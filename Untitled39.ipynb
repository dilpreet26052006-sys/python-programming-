# %%
import numpy as np

# %%
data=[4,2,5,8,6,16,4,45,78,45,10,12,13,45,16,18,19,20,22]
len(data)
# Out:
# 19

# %%
x=np.mean(data)
print(x)
# Out:
# 20.42105263157895

# %%
data.sort()

# %%
print(data)
# Out:
# [2, 4, 4, 5, 6, 8, 10, 12, 13, 16, 16, 18, 19, 20, 22, 45, 45, 45, 78]

# %%
data=[4,2,5,8,6,16,4,45,78,45,10,12,13,45,16,18,19,20,22]
x=np.median(data)
print(x)
# Out:
# 16.0

# %%
from scipy import stats
data=[4,2,5,8,6,16,4,45,78,45,10,12,13,45,16,18,19,20,22]
x=stats.mode(data)
print(x)
# Out:
# ModeResult(mode=45, count=3)

# %%
data=[2,4,3,6,7,10,3,9,2,1]
x=np.var(data)
print(x)
# Out:
# 8.809999999999999

# %%
np.std(data)
# Out:
# 2.9681644159311658
