# %%
l=[45,46,"apple",12.6,"Banana",55,42,1,3,7]
print(l[0])
print(l[1])
print(l[2])
print(l[3])
print(l[4])
# Out:
# 45
# 46
# apple
# 12.6
# Banana

# %%
l=[45,46,"apple",12.6,"Banana",55,42,1,3,7]
for i in l:
    print(i)
# Out:
# 45
# 46
# apple
# 12.6
# Banana
# 55
# 42
# 1
# 3
# 7

# %%
l=[45,46,"apple",12.6,"Banana",55,42,1,3,7]
for i in l:
    print(i)
    if i==55:
        break
# Out:
# 45
# 46
# apple
# 12.6
# Banana
# 55

# %%
l=[45,46,"apple",12.6,"Banana",55,42,1,3,7]
for i in l:
    if i==55:
        break
    print(i)
# Out:
# 45
# 46
# apple
# 12.6
# Banana

# %%
l=[75,"Dilpreet",23,60,94,18,"Sidhu",2,3]
for i in l:
    if i==60:
        print("i have exceeded the limit do you want to continue")
        break
    else:
        print(i)
# Out:
# 75
# Dilpreet
# 23
# i have exceeded the limit do you want to continue

# %%
l=[75,"Dilpreet",23,60,94,18,"Sidhu",2,3]
for i in l:
    if i==60:
        print("i have exceeded the limit do you want to continue")
    else:
        print(i)
# Out:
# 75
# Dilpreet
# 23
# i have exceeded the limit do you want to continue
# 94
# 18
# Sidhu
# 2
# 3

# %%
l=[45,46,"apple",12.6,"Banana",55,42,1,3,7]
for i in l:
    if i==55:
        continue
    print(i)
# Out:
# 45
# 46
# apple
# 12.6
# Banana
# 42
# 1
# 3
# 7

# %%
l=[45,46,"apple",12.6,"Banana",55,42,1,3,7]
for i in l:
    pass

# %%
i=1
while i<10:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
i=1
while i<10:
    print(i)
    if i==5:
        break
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
