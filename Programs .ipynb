# %%
n=int(input("enter the num:"))
original=n
sum=0
while n>0:
    d=n%10
    sum=sum+d**3
    n=n//10
if sum==original:
    print("armstrong num")
else:
     print("not an armstrong num")
# Out:
# enter the num:153
# armstrong num

# %%
n=int(input("enter the num:"))
original=n
sum=0
while n>0:
    d=n%10
    sum=sum+d**3
    n=n//10
if sum==original:
    print("armstrong num")
else:
     print("not an armstrong num")
# Out:
# enter the num:157
# not an armstrong num

# %%
n=int(input("enter the num:"))
original=n
sum=0
while n>0:
    d=n%10
    sum=sum+d**4
    n=n//10
if sum==original:
    print("armstrong num")
else:
     print("not an armstrong num")
# Out:
# enter the num:1634
# armstrong num
