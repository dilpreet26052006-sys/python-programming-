# %%
n=int(input("enter the num"))
i=1
count=0
while i>n:
    if n%i==0:
        count=count+1
        i=i+1
    else:
        i=i+1
else:
    if count==0:
        print("the num is a armstrong num")
    else:
        print("the num is not a armstrong num")
# Out:
# enter the num153
# the num is a armstrong num
