# %%
Arithmetic operator
a=10
b=20
print(a+b)
# Out:
# 30

# %%
x=int(input("Enter the value of x:"))
y=int(input("Enter the value of y:"))
print("the Addtion of x & y is:",x+y)
print("the Subtraction of x & y is:",x-y)
print("the Multiplication of x & y is:",x*y)
print("the Divison of x & y is:",x/y)
print("the Floor divison of x & y is:",x//y)
print("the Exponentiation of x & y is:",x**y)
print("the Modulus of x & y is:",x%y)
# Out:
# Enter the value of x:5
# Enter the value of y:50
# the Addtion of x & y is: 55
# the Subtraction of x & y is: -45
# the Multiplication of x & y is: 250
# the Divison of x & y is: 0.1
# the Floor divison of x & y is: 0
# the Exponentiation of x & y is: 88817841970012523233890533447265625
# the Modulus of x & y is: 5

# %%
Assignment operator 
x=5
x=x+3
print(x)
# Out:
# 8

# %%
x=6
x=x-3
print(x)
# Out:
# 3

# %%
x=7
x=x*3
print(x)
# Out:
# 21

# %%
x=8
x=x/3
print(x)
# Out:
# 2.6666666666666665

# %%
x=9
x=x//3
print(x)
# Out:
# 3

# %%
x=10
x=x%3
print(x)
# Out:
# 1

# %%
x=11
x=x**3
print(x)
# Out:
# 1331

# %%
x=5
x=x&3
print(x)
# Out:
# 1

# %%
x=6
x=x|3
print(x)
# Out:
# 7

# %%
x=7
x=x^3
print(x)
# Out:
# 4

# %%
x=5
x=x>>3
print(x)
# Out:
# 0

# %%
x=5
x=x<<3
print(x)
# Out:
# 40

# %%
Comparison operator
x=50
y=20
print(x==y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
print(xx=y)
# Out:
# False
# True
# False
# True
# False

# %%
Logical operator
x=20
y=30
if x==50 and y==30:
    print("True")
else:
    print("False")
# Out:
# False

# %%
x=20
y=30
if x==20 and y==30:
    print("True")
else:
    print("False")
# Out:
# True

# %%
x=20
y=30
if x==20 or y==30:
    print("True")
else:
    print("False")
# Out:
# True

# %%
x=20
y=30
if x==120 or y==30:
    print("True")
else:
    print("False")
# Out:
# True

# %%
x=20
y=30
if x==120 or y==130:
    print("True")
else:
    print("False")
# Out:
# False

# %%
x=True
print(not x)
# Out:
# False

# %%
x=False
print(not x)
# Out:
# True

# %%
x=10
y=10
print(x==y)
print(x is y)
# Out:
# True
# True

# %%
x=256
y=256
print(x==y)
print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# True
# 8893160
# 8893160

# %%
x=280
y=280
print(x==y)
print(x is y)
# Out:
# True
# False

# %%
x=257
y=257
print(x==y)
print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# False
# 140075660073872
# 140075660075472

# %%
x=[5,4,3,2,1]
l=5
l in x
# Out:
# True
