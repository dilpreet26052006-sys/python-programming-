# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={"name":"Zubair","Father_name":"Fayaz_Ah","D.O.B":"1997","Salary":80000,"dept":"CSE"}

# %%
d1
# Out:
# {'name': 'Zubair',
#  'Father_name': 'Fayaz_Ah',
#  'D.O.B': '1997',
#  'Salary': 80000,
#  'dept': 'CSE'}

# %%
d1['name']
# Out:
# 'Zubair'

# %%
d1['name']="Kubair"
print(d1)
# Out:
# {'name': 'Kubair', 'Father_name': 'Fayaz_Ah', 'D.O.B': '1997', 'Salary': 80000, 'dept': 'CSE'}

# %%
d2={'Name': 'Zubair',
 'Father_name': 'Fayaz_Ah',
 'D.O.B': '1997',
 'Salary': 80000,
 'dept': 'CSE',"Name":"XYZ"}

# %%
d2
# Out:
# {'Name': 'XYZ',
#  'Father_name': 'Fayaz_Ah',
#  'D.O.B': '1997',
#  'Salary': 80000,
#  'dept': 'CSE'}

# %%
d3={1:"Dilpreet"}

# %%
d3={(1,2,3):"Dilpreet"}

# %%
d3
# Out:
# {(1, 2, 3): 'Dilpreet'}

# %%
d4={[1,2,3]:"Dilpreet"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 d4={[1,2,3]:"Dilpreet"}
#
# TypeError: unhashable type: 'list'

# %%
d4={"dilpreet":[1,2,3]}

# %%
d4
# Out:
# {'dilpreet': [1, 2, 3]}

# %%
d={'Name': 'Zubair',
 'Father_name': 'Fayaz_Ah',
 'D.O.B': '1997',
 'Salary': 80000,
 'dept': 'CSE'}

# %%
d
# Out:
# {'Name': 'Zubair',
#  'Father_name': 'Fayaz_Ah',
#  'D.O.B': '1997',
#  'Salary': 80000,
#  'dept': 'CSE'}

# %%
d.get('Salary')
# Out:
# 80000

# %%
d['Salary']
# Out:
# 80000

# %%
d.items()
# Out:
# dict_items([('Name', 'Zubair'), ('Father_name', 'Fayaz_Ah'), ('D.O.B', '1997'), ('Salary', 80000), ('dept', 'CSE')])

# %%
d.keys()
# Out:
# dict_keys(['Name', 'Father_name', 'D.O.B', 'Salary', 'dept'])

# %%
d.values()
# Out:
# dict_values(['Zubair', 'Fayaz_Ah', '1997', 80000, 'CSE'])

# %%
s=("Zubair","Fayaz")
s1=1
d.fromkeys(s,s1)
# Out:
# {'Zubair': 1, 'Fayaz': 1}

# %%
d.pop('Name')
# Out:
# 'Zubair'

# %%
d
# Out:
# {'Father_name': 'Fayaz_Ah', 'D.O.B': '1997', 'Salary': 80000, 'dept': 'CSE'}

# %%
d.popitem()
# Out:
# ('dept', 'CSE')

# %%
d.setdefault('D.O.B',2000)
# Out:
# '1997'

# %%
d.update({'D.O.B',2000})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 d.update({'D.O.B',2000})
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
d.setdefault("Name","XYZ")
# Out:
# 'XYZ'

# %%
d.update({"Role":"Teacher"})

# %%
d
# Out:
# {'Father_name': 'Fayaz_Ah',
#  'D.O.B': '1997',
#  'Salary': 80000,
#  'Name': 'XYZ',
#  'Role': 'Teacher'}

# %%
d={"Fruits":["Banana","Orange","Papaya","Grapes"]},
  "Size":[20,30,50,12],
  "Weight":[40,80,1000,123],
 "Color":['Yellow','Orange','Yellow','Green']}
# Out:
#   File <tokenize>:4
#     "Color":['Yellow','Orange','Yellow','Green']}
#     ^
# IndentationError: unindent does not match any outer indentation level
