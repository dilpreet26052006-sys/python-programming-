# %%
x=10
x=20
y="dilpreet"

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
num=30
dilpreet="Dilpreet"#valid

# %%
num_1=10#valid
_num=10#valid
num-1=10
# Out:
#   Cell In[12], line 3
#     num-1=10
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
dilpreet=30 #valid

# %%
dilpreet-3=30 #invalid
# Out:
#   Cell In[15], line 1
#     dilpreet-3=30
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
_dilpreet=30 #valid

# %%
dilpreet="Dilpreet" #valid

# %%
x=3==30 #valid
