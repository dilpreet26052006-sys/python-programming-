# %%
s={}
s1={1}
print(type(s))
print(type(s1))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
s={"name":"dilpreet"}
s1={1,2,5,4,7}
print(type(s))
print(type(s1))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
# set contains variety of data in a single variable
s={1,5,9,8,2,1,1,0,0,0,"dilpreet",23.56}

# %%
s
# Out:
# {0, 1, 2, 23.56, 5, 8, 9, 'dilpreet'}

# %%
# set is unordered,unchangeable,unindexed,
# does not allow duplicate

# %%
# unordered
s1={4,5,8,2,1,0,6,3,7}
print(s1)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
# not allow duplicates
s2={5,6,2,5,3,5,4,9,4,8,2,0,0,1,4,1,4}
print(s2)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 8, 9}

# %%
# unindexed 
s3={6,8,2,4,6,3,1,0,1,0}
print(s3)
# Out:
# {0, 1, 2, 3, 4, 6, 8}

# %%
s3[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s3[2]
#
# TypeError: 'set' object is not subscriptable

# %%
s4={5,4,2,True,4,1,0,8,9,False}
print(s4)
# Out:
# {0, True, 2, 4, 5, 8, 9}

# %%
s4[5]="dilpreet"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s4[5]="dilpreet"
#
# TypeError: 'set' object does not support item assignment

# %%
# set Methods

# %%
s5={5,True,False,5,"Dilpreet","Yash",7,8,5,6}

# %%
s5.add("Sidhu")
print(s5)
# Out:
# {False, True, 5, 6, 7, 8, 'Yash', 'Sidhu', 'Dilpreet'}

# %%
s5
# Out:
# {5, 6, 7, 8, 'Dilpreet', False, 'Sidhu', True, 'Yash'}

# %%
x=s5.copy()
print(x)
# Out:
# {False, True, 5, 6, 7, 8, 'Yash', 'Sidhu', 'Dilpreet'}

# %%
s5.discard("Sidhu")
print(s5)
# Out:
# {False, True, 5, 6, 7, 8, 'Yash', 'Dilpreet'}

# %%
s={4,5,6,8,9,2,1,32}
s1={"Dilpreet",5,8,3,4,6}

# %%
print(s.discard(9))
print(s1.remove("Dilpreet"))
# Out:
# None
# None
